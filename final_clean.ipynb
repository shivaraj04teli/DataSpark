# %%
import pandas as pd
import numpy as np
from datetime import datetime

# %%
customer_data = pd.read_csv(r'C:\Users\Shiva\OneDrive\Desktop\DATA_SPARK\Customers.csv', encoding='ISO-8859-1')
customer_data
# Out:
#        CustomerKey  Gender               Name                 City State Code  \
# 0              301  Female      Lilly Harding       WANDEARAH EAST         SA
# 1              325  Female       Madison Hull           MOUNT BUDD         WA
# 2              554  Female      Claire Ferres            WINJALLOK        VIC
# 3              786    Male  Jai Poltpalingada         MIDDLE RIVER         SA
# 4             1042    Male    Aidan Pankhurst        TAWONGA SOUTH        VIC
# ...            ...     ...                ...                  ...        ...
# 15261      2099600  Female     Denisa Duková              Houston         TX
# 15262      2099618    Male   Justin Solórzano               Mclean         VA
# 15263      2099758    Male    Svend Petrussen           Wilmington         NC
# 15264      2099862  Female       Lorenza Rush            Riverside         CA
# 15265      2099937    Male   Zygmunt Kaminski  Bloomfield Township         MI
#
# ...

# %%
customer_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15266 entries, 0 to 15265
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   CustomerKey  15266 non-null  int64
#  1   Gender       15266 non-null  object
#  2   Name         15266 non-null  object
#  3   City         15266 non-null  object
#  4   State Code   15256 non-null  object
#  5   State        15266 non-null  object
#  6   Zip Code     15266 non-null  object
#  7   Country      15266 non-null  object
#  8   Continent    15266 non-null  object
#  9   Birthday     15266 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 1.2+ MB

# %%
customer_data.isnull().sum()
# Out:
# CustomerKey     0
# Gender          0
# Name            0
# City            0
# State Code     10
# State           0
# Zip Code        0
# Country         0
# Continent       0
# Birthday        0
# dtype: int64

# %%
customer_data=customer_data.drop(['State Code'], axis=1)

# %%
customer_data.isnull().sum()
# Out:
# CustomerKey    0
# Gender         0
# Name           0
# City           0
# State          0
# Zip Code       0
# Country        0
# Continent      0
# Birthday       0
# dtype: int64

# %%
customer_data['Birthday'] = pd.to_datetime(customer_data['Birthday'], format='%d-%m-%Y')

# %%
customer_data['Age'] = customer_data['Birthday'].apply(lambda x: datetime.now().year - x.year if pd.notnull(x) else None)

# %%
customer_data
# Out:
#        CustomerKey  Gender               Name                 City  \
# 0              301  Female      Lilly Harding       WANDEARAH EAST
# 1              325  Female       Madison Hull           MOUNT BUDD
# 2              554  Female      Claire Ferres            WINJALLOK
# 3              786    Male  Jai Poltpalingada         MIDDLE RIVER
# 4             1042    Male    Aidan Pankhurst        TAWONGA SOUTH
# ...            ...     ...                ...                  ...
# 15261      2099600  Female     Denisa Duková              Houston
# 15262      2099618    Male   Justin Solórzano               Mclean
# 15263      2099758    Male    Svend Petrussen           Wilmington
# 15264      2099862  Female       Lorenza Rush            Riverside
# 15265      2099937    Male   Zygmunt Kaminski  Bloomfield Township
#
#                    State Zip Code        Country      Continent   Birthday  \
# 0        South Australia     5523      Australia      Australia 1939-07-03
# ...

# %%
customer_data
# Out:
#        CustomerKey  Gender               Name                 City  \
# 0              301  Female      Lilly Harding       WANDEARAH EAST
# 1              325  Female       Madison Hull           MOUNT BUDD
# 2              554  Female      Claire Ferres            WINJALLOK
# 3              786    Male  Jai Poltpalingada         MIDDLE RIVER
# 4             1042    Male    Aidan Pankhurst        TAWONGA SOUTH
# ...            ...     ...                ...                  ...
# 15261      2099600  Female     Denisa Duková              Houston
# 15262      2099618    Male   Justin Solórzano               Mclean
# 15263      2099758    Male    Svend Petrussen           Wilmington
# 15264      2099862  Female       Lorenza Rush            Riverside
# 15265      2099937    Male   Zygmunt Kaminski  Bloomfield Township
#
#                    State Zip Code        Country      Continent   Birthday  \
# 0        South Australia     5523      Australia      Australia 1939-07-03
# ...

# %%
exchange_rates_data=pd.read_csv(r'C:\Users\Shiva\OneDrive\Desktop\DATA_SPARK\Exchange_Rates.csv')
exchange_rates_data
# Out:
#              Date Currency  Exchange
# 0      01-01-2015      USD    1.0000
# 1      01-01-2015      CAD    1.1583
# 2      01-01-2015      AUD    1.2214
# 3      01-01-2015      EUR    0.8237
# 4      01-01-2015      GBP    0.6415
# ...           ...      ...       ...
# 11210   2/20/2021      USD    1.0000
# 11211   2/20/2021      CAD    1.2610
# 11212   2/20/2021      AUD    1.2723
# 11213   2/20/2021      EUR    0.8238
# 11214   2/20/2021      GBP    0.7126
#
# [11215 rows x 3 columns]

# %%
exchange_rates_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11215 entries, 0 to 11214
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      11215 non-null  object
#  1   Currency  11215 non-null  object
#  2   Exchange  11215 non-null  float64
# dtypes: float64(1), object(2)
# memory usage: 263.0+ KB

# %%
exchange_rates_data.isnull().sum()
# Out:
# Date        0
# Currency    0
# Exchange    0
# dtype: int64

# %%
exchange_rates_data['Date']=exchange_rates_data['Date'].apply(lambda x: pd.to_datetime(x).strftime('%d/%m/%Y'))
exchange_rates_data
# Out:
#              Date Currency  Exchange
# 0      01/01/2015      USD    1.0000
# 1      01/01/2015      CAD    1.1583
# 2      01/01/2015      AUD    1.2214
# 3      01/01/2015      EUR    0.8237
# 4      01/01/2015      GBP    0.6415
# ...           ...      ...       ...
# 11210  20/02/2021      USD    1.0000
# 11211  20/02/2021      CAD    1.2610
# 11212  20/02/2021      AUD    1.2723
# 11213  20/02/2021      EUR    0.8238
# 11214  20/02/2021      GBP    0.7126
#
# [11215 rows x 3 columns]

# %%
exchange_rates_data.rename(columns={'Currency': 'Currency_Notation'}, inplace=True)

# %%
exchange_rates_data
# Out:
#              Date Currency_Notation  Exchange
# 0      01/01/2015               USD    1.0000
# 1      01/01/2015               CAD    1.1583
# 2      01/01/2015               AUD    1.2214
# 3      01/01/2015               EUR    0.8237
# 4      01/01/2015               GBP    0.6415
# ...           ...               ...       ...
# 11210  20/02/2021               USD    1.0000
# 11211  20/02/2021               CAD    1.2610
# 11212  20/02/2021               AUD    1.2723
# 11213  20/02/2021               EUR    0.8238
# 11214  20/02/2021               GBP    0.7126
#
# [11215 rows x 3 columns]

# %%
products_data=pd.read_csv(r'C:\Users\Shiva\OneDrive\Desktop\DATA_SPARK\Products.csv')

# %%
products_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2517 entries, 0 to 2516
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ProductKey      2517 non-null   int64
#  1   Product Name    2517 non-null   object
#  2   Brand           2517 non-null   object
#  3   Color           2517 non-null   object
#  4   Unit Cost USD   2517 non-null   object
#  5   Unit Price USD  2517 non-null   object
#  6   SubcategoryKey  2517 non-null   int64
#  7   Subcategory     2517 non-null   object
#  8   CategoryKey     2517 non-null   int64
#  9   Category        2517 non-null   object
# dtypes: int64(3), object(7)
# memory usage: 196.8+ KB

# %%
products_data.isnull().sum()
# Out:
# ProductKey        0
# Product Name      0
# Brand             0
# Color             0
# Unit Cost USD     0
# Unit Price USD    0
# SubcategoryKey    0
# Subcategory       0
# CategoryKey       0
# Category          0
# dtype: int64

# %%
products_data
# Out:
#       ProductKey                                   Product Name    Brand  \
# 0              1            Contoso 512MB MP3 Player E51 Silver  Contoso
# 1              2              Contoso 512MB MP3 Player E51 Blue  Contoso
# 2              3               Contoso 1G MP3 Player E100 White  Contoso
# 3              4              Contoso 2G MP3 Player E200 Silver  Contoso
# 4              5                 Contoso 2G MP3 Player E200 Red  Contoso
# ...          ...                                            ...      ...
# 2512        2513    Contoso Bluetooth Active Headphones L15 Red  Contoso
# 2513        2514  Contoso Bluetooth Active Headphones L15 White  Contoso
# 2514        2515             Contoso In-Line Coupler E180 White  Contoso
# 2515        2516             Contoso In-Line Coupler E180 Black  Contoso
# 2516        2517            Contoso In-Line Coupler E180 Silver  Contoso
#
#        Color Unit Cost USD Unit Price USD  SubcategoryKey  \
# ...

# %%
products_data['Unit Cost USD']=products_data['Unit Cost USD'].str.replace('$','').str.replace(',','')
products_data['Unit Cost USD']=products_data['Unit Cost USD'].astype(float)

# %%
products_data['Unit Price USD']=products_data['Unit Price USD'].str.replace('$','').str.replace(',','')
products_data['Unit Price USD']=products_data['Unit Price USD'].astype(float)

# %%
products_data
# Out:
#       ProductKey                                   Product Name    Brand  \
# 0              1            Contoso 512MB MP3 Player E51 Silver  Contoso
# 1              2              Contoso 512MB MP3 Player E51 Blue  Contoso
# 2              3               Contoso 1G MP3 Player E100 White  Contoso
# 3              4              Contoso 2G MP3 Player E200 Silver  Contoso
# 4              5                 Contoso 2G MP3 Player E200 Red  Contoso
# ...          ...                                            ...      ...
# 2512        2513    Contoso Bluetooth Active Headphones L15 Red  Contoso
# 2513        2514  Contoso Bluetooth Active Headphones L15 White  Contoso
# 2514        2515             Contoso In-Line Coupler E180 White  Contoso
# 2515        2516             Contoso In-Line Coupler E180 Black  Contoso
# 2516        2517            Contoso In-Line Coupler E180 Silver  Contoso
#
#        Color  Unit Cost USD  Unit Price USD  SubcategoryKey  \
# ...

# %%
sales_data=pd.read_csv(r'C:\Users\Shiva\OneDrive\Desktop\DATA_SPARK\Sales.csv')

# %%
sales_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62884 entries, 0 to 62883
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order Number   62884 non-null  int64
#  1   Line Item      62884 non-null  int64
#  2   Order Date     62884 non-null  object
#  3   Delivery Date  13165 non-null  object
#  4   CustomerKey    62884 non-null  int64
#  5   StoreKey       62884 non-null  int64
#  6   ProductKey     62884 non-null  int64
#  7   Quantity       62884 non-null  int64
#  8   Currency Code  62884 non-null  object
# dtypes: int64(6), object(3)
# memory usage: 4.3+ MB

# %%
sales_data.isnull().sum()
# Out:
# Order Number         0
# Line Item            0
# Order Date           0
# Delivery Date    49719
# CustomerKey          0
# StoreKey             0
# ProductKey           0
# Quantity             0
# Currency Code        0
# dtype: int64

# %%
sales_data=sales_data.drop(['Delivery Date'],axis=1)

# %%
sales_data
# Out:
#        Order Number  Line Item Order Date  CustomerKey  StoreKey  ProductKey  \
# 0            366000          1   1/1/2016       265598        10        1304
# 1            366001          1   1/1/2016      1269051         0        1048
# 2            366001          2   1/1/2016      1269051         0        2007
# 3            366002          1   1/1/2016       266019         0        1106
# 4            366002          2   1/1/2016       266019         0         373
# ...             ...        ...        ...          ...       ...         ...
# 62879       2243030          1  2/20/2021      1216913        43         632
# 62880       2243031          1  2/20/2021       511229         0          98
# 62881       2243032          1  2/20/2021       331277         0        1613
# 62882       2243032          2  2/20/2021       331277         0        1717
# 62883       2243032          3  2/20/2021       331277         0         464
#
#        Quantity Currency Code
# ...

# %%
sales_data['Order Date']=sales_data['Order Date'].apply(lambda x: pd.to_datetime(x).strftime('%d/%m/%Y'))

# %%
stores_data=pd.read_csv(r'C:\Users\Shiva\OneDrive\Desktop\DATA_SPARK\Stores.csv')

# %%
stores_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67 entries, 0 to 66
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   StoreKey       67 non-null     int64
#  1   Country        67 non-null     object
#  2   State          67 non-null     object
#  3   Square Meters  66 non-null     float64
#  4   Open Date      67 non-null     object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 2.7+ KB

# %%
stores_data.isnull().sum()
# Out:
# StoreKey         0
# Country          0
# State            0
# Square Meters    1
# Open Date        0
# dtype: int64

# %%
stores_data['Square Meters']=stores_data['Square Meters'].fillna(0)

# %%
stores_data
# Out:
#     StoreKey        Country                         State  Square Meters  \
# 0          1      Australia  Australian Capital Territory          595.0
# 1          2      Australia            Northern Territory          665.0
# 2          3      Australia               South Australia         2000.0
# 3          4      Australia                      Tasmania         2000.0
# 4          5      Australia                      Victoria         2000.0
# ..       ...            ...                           ...            ...
# 62        63  United States                          Utah         2000.0
# 63        64  United States                 Washington DC         1330.0
# 64        65  United States                 West Virginia         1785.0
# 65        66  United States                       Wyoming          840.0
# 66         0         Online                        Online            0.0
#
#      Open Date
# 0   01-01-2008
# 1   01-12-2008
# 2   01-07-2012
# 3   01-01-2010
# ...

# %%
stores_data['Open Date']=stores_data['Open Date'].apply(lambda x: pd.to_datetime(x).strftime('%d-%m-%y'))

# %%
stores_data
# Out:
#     StoreKey        Country                         State  Square Meters  \
# 0          1      Australia  Australian Capital Territory          595.0
# 1          2      Australia            Northern Territory          665.0
# 2          3      Australia               South Australia         2000.0
# 3          4      Australia                      Tasmania         2000.0
# 4          5      Australia                      Victoria         2000.0
# ..       ...            ...                           ...            ...
# 62        63  United States                          Utah         2000.0
# 63        64  United States                 Washington DC         1330.0
# 64        65  United States                 West Virginia         1785.0
# 65        66  United States                       Wyoming          840.0
# 66         0         Online                        Online            0.0
#
#    Open Date
# 0   01-01-08
# 1   12-01-08
# 2   07-01-12
# 3   01-01-10
# 4   09-12-15
# ...

# %%
print("Sales columns:")
print(sales_data.columns.tolist())
# Out:
# Sales columns:
# ['Order Number', 'Line Item', 'Order Date', 'CustomerKey', 'StoreKey', 'ProductKey', 'Quantity', 'Currency Code']

# %%
sales = sales_data[[
    'Order Number', 'Order Date', 'CustomerKey', 
    'StoreKey', 'ProductKey', 'Quantity', 'Currency Code'
]]

# %%
sales
# Out:
#        Order Number  Order Date  CustomerKey  StoreKey  ProductKey  Quantity  \
# 0            366000  01/01/2016       265598        10        1304         1
# 1            366001  01/01/2016      1269051         0        1048         2
# 2            366001  01/01/2016      1269051         0        2007         1
# 3            366002  01/01/2016       266019         0        1106         7
# 4            366002  01/01/2016       266019         0         373         1
# ...             ...         ...          ...       ...         ...       ...
# 62879       2243030  20/02/2021      1216913        43         632         3
# 62880       2243031  20/02/2021       511229         0          98         4
# 62881       2243032  20/02/2021       331277         0        1613         2
# 62882       2243032  20/02/2021       331277         0        1717         2
# 62883       2243032  20/02/2021       331277         0         464         7
#
#       Currency Code
# 0               CAD
# ...

# %%
customer_data
# Out:
#        CustomerKey  Gender               Name                 City  \
# 0              301  Female      Lilly Harding       WANDEARAH EAST
# 1              325  Female       Madison Hull           MOUNT BUDD
# 2              554  Female      Claire Ferres            WINJALLOK
# 3              786    Male  Jai Poltpalingada         MIDDLE RIVER
# 4             1042    Male    Aidan Pankhurst        TAWONGA SOUTH
# ...            ...     ...                ...                  ...
# 15261      2099600  Female     Denisa Duková              Houston
# 15262      2099618    Male   Justin Solórzano               Mclean
# 15263      2099758    Male    Svend Petrussen           Wilmington
# 15264      2099862  Female       Lorenza Rush            Riverside
# 15265      2099937    Male   Zygmunt Kaminski  Bloomfield Township
#
#                    State Zip Code        Country      Continent   Birthday  \
# 0        South Australia     5523      Australia      Australia 1939-07-03
# ...

# %%
del customer

# %%
customer=customer_data[['CustomerKey', 'Gender', 'Country', 
    'State', 'City','Continent','Birthday','Age'
]]
customer
# Out:
#        CustomerKey  Gender        Country              State  \
# 0              301  Female      Australia    South Australia
# 1              325  Female      Australia  Western Australia
# 2              554  Female      Australia           Victoria
# 3              786    Male      Australia    South Australia
# 4             1042    Male      Australia           Victoria
# ...            ...     ...            ...                ...
# 15261      2099600  Female  United States              Texas
# 15262      2099618    Male  United States           Virginia
# 15263      2099758    Male  United States     North Carolina
# 15264      2099862  Female  United States         California
# 15265      2099937    Male  United States           Michigan
#
#                       City      Continent   Birthday  Age
# 0           WANDEARAH EAST      Australia 1939-07-03   85
# 1               MOUNT BUDD      Australia 1979-09-27   45
# ...

# %%
print("\nProducts columns:")
print(products_data.columns.tolist())
# Out:
# Products columns:
# ['ProductKey', 'Product Name', 'Brand', 'Color', 'Unit Cost USD', 'Unit Price USD', 'SubcategoryKey', 'Subcategory', 'CategoryKey', 'Category']

# %%
products=products_data[['ProductKey', 'Product Name', 'Category', 
    'Subcategory', 'Unit Cost USD', 'Unit Price USD','Brand','Color']]
products
# Out:
#       ProductKey                                   Product Name     Category  \
# 0              1            Contoso 512MB MP3 Player E51 Silver        Audio
# 1              2              Contoso 512MB MP3 Player E51 Blue        Audio
# 2              3               Contoso 1G MP3 Player E100 White        Audio
# 3              4              Contoso 2G MP3 Player E200 Silver        Audio
# 4              5                 Contoso 2G MP3 Player E200 Red        Audio
# ...          ...                                            ...          ...
# 2512        2513    Contoso Bluetooth Active Headphones L15 Red  Cell phones
# 2513        2514  Contoso Bluetooth Active Headphones L15 White  Cell phones
# 2514        2515             Contoso In-Line Coupler E180 White  Cell phones
# 2515        2516             Contoso In-Line Coupler E180 Black  Cell phones
# 2516        2517            Contoso In-Line Coupler E180 Silver  Cell phones
#
# ...

# %%
print("\nStores columns:")
print(stores_data.columns.tolist())
# Out:
# Stores columns:
# ['StoreKey', 'Country', 'State', 'Square Meters', 'Open Date']

# %%
stores=stores_data[['StoreKey', 'Country', 'State', 
    'Square Meters', 'Open Date']]

# %%
print("\nExchange Rates columns:")
print(exchange_rates_data.columns.tolist())
# Out:
# Exchange Rates columns:
# ['Date', 'Currency_Notation', 'Exchange']

# %%
exchange_rates = exchange_rates_data[[
    'Date', 'Currency_Notation', 'Exchange']]

# %%
del products

# %%
pip install mysql-connector-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import mysql.connector
con= mysql.connector.connect(
    host="localhost",
    user="root",
    password="AKSBRSt@2000",
    auth_plugin="mysql_native_password"
    )
print(con)

# %%
customer
# Out:
#        CustomerKey  Gender        Country              State  \
# 0              301  Female      Australia    South Australia
# 1              325  Female      Australia  Western Australia
# 2              554  Female      Australia           Victoria
# 3              786    Male      Australia    South Australia
# 4             1042    Male      Australia           Victoria
# ...            ...     ...            ...                ...
# 15261      2099600  Female  United States              Texas
# 15262      2099618    Male  United States           Virginia
# 15263      2099758    Male  United States     North Carolina
# 15264      2099862  Female  United States         California
# 15265      2099937    Male  United States           Michigan
#
#                       City      Continent   Birthday  Age
# 0           WANDEARAH EAST      Australia 1939-07-03   85
# 1               MOUNT BUDD      Australia 1979-09-27   45
# ...

# %%
my_cursor=con.cursor()
my_cursor.execute("use dataspark")
my_cursor.execute('''
CREATE TABLE IF NOT EXISTS customer_data(
CustomerKey INT AUTO_INCREMENT PRIMARY KEY,
Gender VARCHAR(255), 
Country VARCHAR(255), 
State VARCHAR(255),
City  VARCHAR(255),
Continent VARCHAR(255),
Birthday DATE,                  
Age INT
)''')

print("Table Created successfully")
# Out:
# Table Created successfully

# %%
insert_query = '''INSERT INTO customer_data (
    CustomerKey,
    Gender,
    Country,
    State,
    City,
    Continent,
    Birthday,
    Age)
    VALUES (%s, %s, %s, %s, %s, %s, %s, %s)'''

customer_data = customer.values.tolist()
my_cursor.executemany(insert_query, customer_data)
con.commit()

print("Values inserted successfully")
# Out:
# Values inserted successfully

# %%
exchange_rates
# Out:
#              Date Currency_Notation  Exchange
# 0      01/01/2015               USD    1.0000
# 1      01/01/2015               CAD    1.1583
# 2      01/01/2015               AUD    1.2214
# 3      01/01/2015               EUR    0.8237
# 4      01/01/2015               GBP    0.6415
# ...           ...               ...       ...
# 11210  20/02/2021               USD    1.0000
# 11211  20/02/2021               CAD    1.2610
# 11212  20/02/2021               AUD    1.2723
# 11213  20/02/2021               EUR    0.8238
# 11214  20/02/2021               GBP    0.7126
#
# [11215 rows x 3 columns]

# %%
exchange_rates = [
    (datetime.strptime(row[0], '%d/%m/%Y').strftime('%Y-%m-%d'), row[1], row[2])
    for row in exchange_rates.values.tolist()
]

# %%
exchange_rates
# Out:
# [('2015-01-01', 'USD', 1.0),
#  ('2015-01-01', 'CAD', 1.1583),
#  ('2015-01-01', 'AUD', 1.2214),
#  ('2015-01-01', 'EUR', 0.8237),
#  ('2015-01-01', 'GBP', 0.6415),
#  ('2015-01-02', 'USD', 1.0),
#  ('2015-01-02', 'CAD', 1.1682),
#  ('2015-01-02', 'AUD', 1.2323),
#  ('2015-01-02', 'EUR', 0.8304),
#  ('2015-01-02', 'GBP', 0.6477),
#  ('2015-01-03', 'USD', 1.0),
#  ('2015-01-03', 'CAD', 1.1682),
#  ('2015-01-03', 'AUD', 1.2323),
#  ('2015-01-03', 'EUR', 0.8304),
#  ('2015-01-03', 'GBP', 0.6477),
#  ('2015-01-04', 'USD', 1.0),
#  ('2015-01-04', 'CAD', 1.1682),
#  ('2015-01-04', 'AUD', 1.2323),
#  ('2015-01-04', 'EUR', 0.8304),
#  ('2015-01-04', 'GBP', 0.6477),
#  ('2015-01-05', 'USD', 1.0),
#  ('2015-01-05', 'CAD', 1.1784),
#  ('2015-01-05', 'AUD', 1.2384),
#  ('2015-01-05', 'EUR', 0.8393),
#  ('2015-01-05', 'GBP', 0.6569),
#  ('2015-01-06', 'USD', 1.0),
#  ('2015-01-06', 'CAD', 1.1763),
#  ('2015-01-06', 'AUD', 1.2288),
#  ('2015-01-06', 'EUR', 0.8393),
# ...

# %%
my_cursor.execute('''
CREATE TABLE IF NOT EXISTS exchange_rates(
Date DATE,
Currency_Notation VARCHAR(255), 
Exchange FLOAT
)''')

print("Table Created successfully")
# Out:
# Table Created successfully

# %%
insert_query = '''INSERT INTO exchange_rates (
    Date,
    Currency_Notation,
    Exchange)
    VALUES (%s, %s, %s)'''

my_cursor.executemany(insert_query, exchange_rates)
con.commit()

print("Values inserted successfully")
# Out:
# Values inserted successfully

# %%
print("\nproducts:")
print(products.columns.tolist())
# Out:
# products:
# ['ProductKey', 'Product Name', 'Category', 'Subcategory', 'Unit Cost USD', 'Unit Price USD', 'Brand', 'Color']

# %%
products = products.rename(columns={'Product Name': 'ProductName'})

# %%
products = products.rename(columns={'Unit Cost USD': 'Unit_Cost_USD'})
products = products.rename(columns={'Unit Price USD': 'Unit_Price_USD'})

# %%
products
# Out:
#       ProductKey                                    ProductName     Category  \
# 0              1            Contoso 512MB MP3 Player E51 Silver        Audio
# 1              2              Contoso 512MB MP3 Player E51 Blue        Audio
# 2              3               Contoso 1G MP3 Player E100 White        Audio
# 3              4              Contoso 2G MP3 Player E200 Silver        Audio
# 4              5                 Contoso 2G MP3 Player E200 Red        Audio
# ...          ...                                            ...          ...
# 2512        2513    Contoso Bluetooth Active Headphones L15 Red  Cell phones
# 2513        2514  Contoso Bluetooth Active Headphones L15 White  Cell phones
# 2514        2515             Contoso In-Line Coupler E180 White  Cell phones
# 2515        2516             Contoso In-Line Coupler E180 Black  Cell phones
# 2516        2517            Contoso In-Line Coupler E180 Silver  Cell phones
#
# ...

# %%
my_cursor.execute('''
CREATE TABLE IF NOT EXISTS products_data(
ProductKey INT PRIMARY KEY,
ProductName VARCHAR(255),
Category VARCHAR(255),        
Subcategory VARCHAR(255),
Unit_Cost_USD VARCHAR(255),
Unit_Price_USD  VARCHAR(255),
Brand VARCHAR(255),
Color VARCHAR(255)
)''')

print("Table Created successfully")
# Out:
# Table Created successfully

# %%
insert_query = '''INSERT INTO products_data (
    ProductKey,
    ProductName,
    Category,
    Subcategory,
    Unit_Cost_USD,
    Unit_Price_USD,
    Brand,
    Color)
    VALUES (%s, %s, %s, %s, %s, %s, %s, %s)'''

products_data = products.values.tolist()
my_cursor.executemany(insert_query, products_data)
con.commit()

print("Values inserted successfully")
# Out:
# Values inserted successfully

# %%
print("Sales columns:")
print(sales.columns.tolist())
# Out:
# Sales columns:
# ['Order Number', 'Order Date', 'CustomerKey', 'StoreKey', 'ProductKey', 'Quantity', 'Currency Code']

# %%
Sales = sales.rename(columns={'Order Number': 'OrderNumber'})
Sales = Sales.rename(columns={'Order Date': 'OrderDate'})
Sales = Sales.rename(columns={'Currency Code': 'CurrencyCode'})

# %%
Sales
# Out:
#        OrderNumber   OrderDate  CustomerKey  StoreKey  ProductKey  Quantity  \
# 0           366000  01/01/2016       265598        10        1304         1
# 1           366001  01/01/2016      1269051         0        1048         2
# 2           366001  01/01/2016      1269051         0        2007         1
# 3           366002  01/01/2016       266019         0        1106         7
# 4           366002  01/01/2016       266019         0         373         1
# ...            ...         ...          ...       ...         ...       ...
# 62879      2243030  20/02/2021      1216913        43         632         3
# 62880      2243031  20/02/2021       511229         0          98         4
# 62881      2243032  20/02/2021       331277         0        1613         2
# 62882      2243032  20/02/2021       331277         0        1717         2
# 62883      2243032  20/02/2021       331277         0         464         7
#
#       CurrencyCode
# 0              CAD
# ...

# %%
my_cursor.execute('''
CREATE TABLE IF NOT EXISTS sales_data(
OrderNumber INT,
OrderDate DATE,
CustomerKey INT,        
StoreKey INT,
ProductKey INT,
Quantity  INT,
CurrencyCode VARCHAR(255)
)''')

print("Table Created successfully")
# Out:
# Table Created successfully

# %%
insert_query = '''INSERT INTO sales_data (
    OrderNumber,
    OrderDate,
    CustomerKey,
    StoreKey,
    ProductKey,
    Quantity,
    CurrencyCode)
    VALUES (%s, %s, %s, %s, %s, %s, %s)'''

sales_data = Sales.values.tolist()
my_cursor.executemany(insert_query, sales_data)
con.commit()

print("Values inserted successfully")
# Out:
# Values inserted successfully

# %%
print("\nStores columns:")
print(stores.columns.tolist())
# Out:
# Stores columns:
# ['StoreKey', 'Country', 'State', 'Square Meters', 'Open Date']

# %%
stores = stores.rename(columns={'Square Meters': 'SquareMeters'})

# %%
stores = stores.rename(columns={'Open Date': 'Open_Date'})

# %%
stores
# Out:
#     StoreKey        Country                         State  SquareMeters  \
# 0          1      Australia  Australian Capital Territory         595.0
# 1          2      Australia            Northern Territory         665.0
# 2          3      Australia               South Australia        2000.0
# 3          4      Australia                      Tasmania        2000.0
# 4          5      Australia                      Victoria        2000.0
# ..       ...            ...                           ...           ...
# 62        63  United States                          Utah        2000.0
# 63        64  United States                 Washington DC        1330.0
# 64        65  United States                 West Virginia        1785.0
# 65        66  United States                       Wyoming         840.0
# 66         0         Online                        Online           0.0
#
#    Open_Date
# 0   01-01-08
# 1   12-01-08
# 2   07-01-12
# 3   01-01-10
# 4   09-12-15
# ..       ...
# ...

# %%
my_cursor.execute('''
CREATE TABLE IF NOT EXISTS stores_data(
StoreKey INT,
Country VARCHAR(255),
State VARCHAR(255),        
SquareMeters FLOAT,
Open_Date DATE
)''')

print("Table Created successfully")
# Out:
# Table Created successfully

# %%
insert_query = '''INSERT INTO stores_data (
    StoreKey,
    Country,
    State,
    SquareMeters,
    Open_Date)
    VALUES (%s, %s, %s, %s, %s)'''

stores_data = stores.values.tolist()
my_cursor.executemany(insert_query, stores_data)
con.commit()

print("Values inserted successfully")
# Out:
# Values inserted successfully
